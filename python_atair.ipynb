# %%
import pandas as pd
import requests
import os
import altair as alt

# %%
SECTORS_API_KEY = os.getenv("SECTORS_API_KEY")
headers = {"Authorization": SECTORS_API_KEY}
response = requests.get("https://api.sectors.app/v1/subsectors/", headers = headers)

if response.status_code == 200:
    data_all_subsectors = response.json()
else:
    # Handle error
    print(response.status_code)

# %%
data_all_subsectors
# Out:
# [{'sector': 'infrastructures', 'subsector': 'telecommunication'},
#  {'sector': 'energy', 'subsector': 'oil-gas-coal'},
#  {'sector': 'financials', 'subsector': 'financing-service'},
#  {'sector': 'financials', 'subsector': 'investment-service'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'apparel-luxury-goods'},
#  {'sector': 'technology', 'subsector': 'software-it-services'},
#  {'sector': 'financials', 'subsector': 'insurance'},
#  {'sector': 'infrastructures',
#   'subsector': 'heavy-constructions-civil-engineering'},
#  {'sector': 'financials', 'subsector': 'banks'},
#  {'sector': 'financials', 'subsector': 'holding-investment-companies'},
#  {'sector': 'industrials', 'subsector': 'industrial-services'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'consumer-services'},
#  {'sector': 'infrastructures', 'subsector': 'utilities'},
#  {'sector': 'consumer-non-cyclicals', 'subsector': 'tobacco'},
#  {'sector': 'transportation-logistic', 'subsector': 'logistics-deliveries'},
#  {'sector': 'industrials', 'subsector': 'multi-sector-holdings'},
#  {'sector': 'healthcare', 'subsector': 'healthcare-equipment-providers'},
#  {'sector': 'energy', 'subsector': 'alternative-energy'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'automobiles-components'},
#  {'sector': 'healthcare', 'subsector': 'pharmaceuticals-health-care-research'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'media-entertainment'},
#  {'sector': 'basic-materials', 'subsector': 'basic-materials'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'household-goods'},
#  {'sector': 'technology', 'subsector': 'technology-hardware-equipment'},
#  {'sector': 'properties-real-estate', 'subsector': 'properties-real-estate'},
#  {'sector': 'industrials', 'subsector': 'industrial-goods'},
#  {'sector': 'transportation-logistic', 'subsector': 'transportation'},
#  {'sector': 'consumer-non-cyclicals',
#   'subsector': 'nondurable-household-products'},
#  {'sector': 'infrastructures', 'subsector': 'transportation-infrastructure'},
#  {'sector': 'consumer-non-cyclicals', 'subsector': 'food-staples-retailing'},
#  {'sector': 'consumer-non-cyclicals', 'subsector': 'food-beverage'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'leisure-goods'},
#  {'sector': 'consumer-cyclicals', 'subsector': 'retailing'}]

# %%
df = pd.DataFrame(data_all_subsectors)
df = df.drop(["sector"], axis=1)
df.head()
# Out:
#               subsector
# 0     telecommunication
# 1          oil-gas-coal
# 2     financing-service
# 3    investment-service
# 4  apparel-luxury-goods

# %%
df["subsector"] = df["subsector"].str.replace("-"," ")
df["subsector"] = df["subsector"].str.title()
df.head()
# Out:
#               subsector
# 0     Telecommunication
# 1          Oil Gas Coal
# 2     Financing Service
# 3    Investment Service
# 4  Apparel Luxury Goods

# %%
result_data = []
for data in data_all_subsectors:
    subsector = data["subsector"]
    headers = {"Authorization": SECTORS_API_KEY}

    response = requests.get(f"https://api.sectors.app/v1/companies/?sub_sector={subsector}", headers = headers)

    if response.status_code == 200:
        list_companies_by_subsectors = response.json()
        for company in list_companies_by_subsectors:
            result_data.append([subsector, company["symbol"]])
    else:
        # Handle error
        print("Error Status :",response.status_code)

result_data
# Out:
# [['telecommunication', 'BALI.JK'],
#  ['telecommunication', 'ISAT.JK'],
#  ['telecommunication', 'MTEL.JK'],
#  ['telecommunication', 'IBST.JK'],
#  ['telecommunication', 'TLKM.JK'],
#  ['telecommunication', 'TBIG.JK'],
#  ['telecommunication', 'LCKM.JK'],
#  ['telecommunication', 'EXCL.JK'],
#  ['telecommunication', 'LINK.JK'],
#  ['telecommunication', 'TOWR.JK'],
#  ['telecommunication', 'GHON.JK'],
#  ['telecommunication', 'KETR.JK'],
#  ['telecommunication', 'MORA.JK'],
#  ['telecommunication', 'INET.JK'],
#  ['telecommunication', 'SUPR.JK'],
#  ['telecommunication', 'OASA.JK'],
#  ['telecommunication', 'BTEL.JK'],
#  ['telecommunication', 'CENT.JK'],
#  ['telecommunication', 'FREN.JK'],
#  ['telecommunication', 'KBLV.JK'],
#  ['telecommunication', 'DATA.JK'],
#  ['telecommunication', 'JAST.JK'],
#  ['telecommunication', 'GOLD.JK'],
#  ['oil-gas-coal', 'AKRA.JK'],
#  ['oil-gas-coal', 'SUNI.JK'],
#  ['oil-gas-coal', 'ABMM.JK'],
#  ['oil-gas-coal', 'GEMS.JK'],
#  ['oil-gas-coal', 'SICO.JK'],
#  ['oil-gas-coal', 'PTRO.JK'],
#  ['oil-gas-coal', 'PSSI.JK'],
#  ['oil-gas-coal', 'MEDC.JK'],
#  ['oil-gas-coal', 'MBAP.JK'],
#  ['oil-gas-coal', 'BSML.JK'],
#  ['oil-gas-coal', 'RAJA.JK'],
#  ['oil-gas-coal', 'PGAS.JK'],
#  ['oil-gas-coal', 'HRUM.JK'],
#  ['oil-gas-coal', 'BYAN.JK'],
#  ['oil-gas-coal', 'SHIP.JK'],
#  ['oil-gas-coal', 'MCOL.JK'],
#  ['oil-gas-coal', 'KKGI.JK'],
#  ['oil-gas-coal', 'TCPI.JK'],
#  ['oil-gas-coal', 'TOBA.JK'],
#  ['oil-gas-coal', 'TEBE.JK'],
#  ['oil-gas-coal', 'SMMT.JK'],
#  ['oil-gas-coal', 'DOID.JK'],
#  ['oil-gas-coal', 'RMKE.JK'],
#  ['oil-gas-coal', 'BSSR.JK'],
#  ['oil-gas-coal', 'MYOH.JK'],
#  ['oil-gas-coal', 'ELSA.JK'],
#  ['oil-gas-coal', 'TPMA.JK'],
#  ['oil-gas-coal', 'INDY.JK'],
#  ['oil-gas-coal', 'ADRO.JK'],
#  ['oil-gas-coal', 'SGER.JK'],
#  ['oil-gas-coal', 'HILL.JK'],
#  ['oil-gas-coal', 'PTBA.JK'],
#  ['oil-gas-coal', 'RUIS.JK'],
#  ['oil-gas-coal', 'GTBO.JK'],
#  ['oil-gas-coal', 'UNIQ.JK'],
#  ['oil-gas-coal', 'ITMG.JK'],
#  ['oil-gas-coal', 'MKAP.JK'],
#  ['oil-gas-coal', 'INPS.JK'],
#  ['oil-gas-coal', 'MAHA.JK'],
#  ['oil-gas-coal', 'APEX.JK'],
#  ['oil-gas-coal', 'WINS.JK'],
#  ['oil-gas-coal', 'ATLA.JK'],
#  ['oil-gas-coal', 'DSSA.JK'],
#  ['oil-gas-coal', 'BULL.JK'],
#  ['oil-gas-coal', 'ARTI.JK'],
#  ['oil-gas-coal', 'RMKO.JK'],
#  ['oil-gas-coal', 'BUMI.JK'],
#  ['oil-gas-coal', 'CANI.JK'],
#  ['oil-gas-coal', 'BESS.JK'],
#  ['oil-gas-coal', 'IATA.JK'],
#  ['oil-gas-coal', 'BIPI.JK'],
#  ['oil-gas-coal', 'CGAS.JK'],
#  ['oil-gas-coal', 'DWGL.JK'],
#  ['oil-gas-coal', 'DEWA.JK'],
#  ['oil-gas-coal', 'HITS.JK'],
#  ['oil-gas-coal', 'RIGS.JK'],
#  ['oil-gas-coal', 'SUGI.JK'],
#  ['oil-gas-coal', 'AIMS.JK'],
#  ['oil-gas-coal', 'SMRU.JK'],
#  ['oil-gas-coal', 'KOPI.JK'],
#  ['oil-gas-coal', 'MTFN.JK'],
#  ['oil-gas-coal', 'RGAS.JK'],
#  ['oil-gas-coal', 'TAMU.JK'],
#  ['oil-gas-coal', 'CUAN.JK'],
#  ['oil-gas-coal', 'PTIS.JK'],
#  ['oil-gas-coal', 'ITMA.JK'],
#  ['oil-gas-coal', 'ALII.JK'],
#  ['oil-gas-coal', 'FIRE.JK'],
#  ['oil-gas-coal', 'TRAM.JK'],
#  ['oil-gas-coal', 'BOSS.JK'],
#  ['oil-gas-coal', 'WOWS.JK'],
#  ['oil-gas-coal', 'COAL.JK'],
#  ['oil-gas-coal', 'LEAD.JK'],
#  ['oil-gas-coal', 'ENRG.JK'],
#  ['oil-gas-coal', 'MBSS.JK'],
#  ['oil-gas-coal', 'HUMI.JK'],
#  ['oil-gas-coal', 'ARII.JK'],
#  ['oil-gas-coal', 'BBRM.JK'],
#  ['oil-gas-coal', 'CNKO.JK'],
#  ['oil-gas-coal', 'PKPK.JK'],
#  ['oil-gas-coal', 'SURE.JK'],
#  ['oil-gas-coal', 'CBRE.JK'],
#  ['oil-gas-coal', 'ADMR.JK'],
#  ['oil-gas-coal', 'GTSI.JK'],
#  ['oil-gas-coal', 'SOCI.JK'],
#  ['financing-service', 'BFIN.JK'],
#  ['financing-service', 'WOMF.JK'],
#  ['financing-service', 'ADMF.JK'],
#  ['financing-service', 'BBLD.JK'],
#  ['financing-service', 'CFIN.JK'],
#  ['financing-service', 'MFIN.JK'],
#  ['financing-service', 'BPFI.JK'],
#  ['financing-service', 'FUJI.JK'],
#  ['financing-service', 'VRNA.JK'],
#  ['financing-service', 'HDFA.JK'],
#  ['financing-service', 'DEFI.JK'],
#  ['financing-service', 'VTNY.JK'],
#  ['financing-service', 'TRUS.JK'],
#  ['financing-service', 'POLA.JK'],
#  ['financing-service', 'TIFA.JK'],
#  ['investment-service', 'RELI.JK'],
#  ['investment-service', 'AMOR.JK'],
#  ['investment-service', 'PANS.JK'],
#  ['investment-service', 'YULE.JK'],
#  ['investment-service', 'TRIM.JK'],
#  ['investment-service', 'PADI.JK'],
#  ['apparel-luxury-goods', 'HRTA.JK'],
#  ['apparel-luxury-goods', 'SRIL.JK'],
#  ['apparel-luxury-goods', 'ERTX.JK'],
#  ['apparel-luxury-goods', 'INOV.JK'],
#  ['apparel-luxury-goods', 'BELL.JK'],
#  ['apparel-luxury-goods', 'TRIS.JK'],
#  ['apparel-luxury-goods', 'ESTI.JK'],
#  ['apparel-luxury-goods', 'INDR.JK'],
#  ['apparel-luxury-goods', 'BATA.JK'],
#  ['apparel-luxury-goods', 'SBAT.JK'],
#  ['apparel-luxury-goods', 'CNTX.JK'],
#  ['apparel-luxury-goods', 'POLU.JK'],
#  ['apparel-luxury-goods', 'MYTX.JK'],
#  ['apparel-luxury-goods', 'UNIT.JK'],
#  ['apparel-luxury-goods', 'POLY.JK'],
#  ['apparel-luxury-goods', 'SSTM.JK'],
#  ['apparel-luxury-goods', 'SPRE.JK'],
#  ['apparel-luxury-goods', 'BIMA.JK'],
#  ['apparel-luxury-goods', 'PBRX.JK'],
#  ['apparel-luxury-goods', 'RICY.JK'],
#  ['apparel-luxury-goods', 'TFCO.JK'],
#  ['apparel-luxury-goods', 'ARGO.JK'],
#  ['apparel-luxury-goods', 'ACRO.JK'],
#  ['apparel-luxury-goods', 'HDTX.JK'],
#  ['software-it-services', 'ELIT.JK'],
#  ['software-it-services', 'WGSH.JK'],
#  ['software-it-services', 'MLPT.JK'],
#  ['software-it-services', 'EMTK.JK'],
#  ['software-it-services', 'UVCR.JK'],
#  ['software-it-services', 'RUNS.JK'],
#  ['software-it-services', 'IRSX.JK'],
#  ['software-it-services', 'WIFI.JK'],
#  ['software-it-services', 'SKYB.JK'],
#  ['software-it-services', 'PGJO.JK'],
#  ['software-it-services', 'BELI.JK'],
#  ['software-it-services', 'NFCX.JK'],
#  ['software-it-services', 'LMAS.JK'],
#  ['software-it-services', 'MCAS.JK'],
#  ['software-it-services', 'CASH.JK'],
#  ['software-it-services', 'ATIC.JK'],
#  ['software-it-services', 'WIRG.JK'],
#  ['software-it-services', 'AREA.JK'],
#  ['software-it-services', 'BUKA.JK'],
#  ['software-it-services', 'TRON.JK'],
#  ['software-it-services', 'EDGE.JK'],
#  ['software-it-services', 'JATI.JK'],
#  ['software-it-services', 'TFAS.JK'],
#  ['software-it-services', 'GOTO.JK'],
#  ['software-it-services', 'DIVA.JK'],
#  ['software-it-services', 'DMMX.JK'],
#  ['software-it-services', 'ENVY.JK'],
#  ['software-it-services', 'CYBR.JK'],
#  ['software-it-services', 'KREN.JK'],
#  ['software-it-services', 'AWAN.JK'],
#  ['software-it-services', 'MPIX.JK'],
#  ['software-it-services', 'KIOS.JK'],
#  ['software-it-services', 'TOSK.JK'],
#  ['software-it-services', 'TECH.JK'],
#  ['software-it-services', 'HDIT.JK'],
#  ['software-it-services', 'DCII.JK'],
#  ['insurance', 'ASDM.JK'],
#  ['insurance', 'ASBI.JK'],
#  ['insurance', 'ASRM.JK'],
#  ['insurance', 'PNLF.JK'],
#  ['insurance', 'VINS.JK'],
#  ['insurance', 'AMAG.JK'],
#  ['insurance', 'ABDA.JK'],
#  ['insurance', 'MREI.JK'],
#  ['insurance', 'TUGU.JK'],
#  ['insurance', 'LPGI.JK'],
#  ['insurance', 'LIFE.JK'],
#  ['insurance', 'JMAS.JK'],
#  ['insurance', 'BHAT.JK'],
#  ['insurance', 'MTWI.JK'],
#  ['insurance', 'PNIN.JK'],
#  ['insurance', 'AHAP.JK'],
#  ['insurance', 'ASMI.JK'],
#  ['insurance', 'ASJT.JK'],
#  ['heavy-constructions-civil-engineering', 'SMKM.JK'],
#  ['heavy-constructions-civil-engineering', 'JKON.JK'],
#  ['heavy-constructions-civil-engineering', 'ADHI.JK'],
#  ['heavy-constructions-civil-engineering', 'PBSA.JK'],
#  ['heavy-constructions-civil-engineering', 'WSKT.JK'],
#  ['heavy-constructions-civil-engineering', 'KRYA.JK'],
#  ['heavy-constructions-civil-engineering', 'TOTL.JK'],
#  ['heavy-constructions-civil-engineering', 'NRCA.JK'],
#  ['heavy-constructions-civil-engineering', 'PPRE.JK'],
#  ['heavy-constructions-civil-engineering', 'IDPR.JK'],
#  ['heavy-constructions-civil-engineering', 'WEGE.JK'],
#  ['heavy-constructions-civil-engineering', 'PTPP.JK'],
#  ['heavy-constructions-civil-engineering', 'WIKA.JK'],
#  ['heavy-constructions-civil-engineering', 'PTPW.JK'],
#  ['heavy-constructions-civil-engineering', 'SSIA.JK'],
#  ['heavy-constructions-civil-engineering', 'ACST.JK'],
#  ['heavy-constructions-civil-engineering', 'BUKK.JK'],
#  ['heavy-constructions-civil-engineering', 'MTPS.JK'],
#  ['heavy-constructions-civil-engineering', 'DGIK.JK'],
#  ['heavy-constructions-civil-engineering', 'PTDU.JK'],
#  ['heavy-constructions-civil-engineering', 'KOKA.JK'],
#  ['heavy-constructions-civil-engineering', 'TAMA.JK'],
#  ['heavy-constructions-civil-engineering', 'FIMP.JK'],
#  ['heavy-constructions-civil-engineering', 'RONY.JK'],
#  ['heavy-constructions-civil-engineering', 'MANG.JK'],
#  ['heavy-constructions-civil-engineering', 'MTRA.JK'],
#  ['heavy-constructions-civil-engineering', 'TOPS.JK'],
#  ['heavy-constructions-civil-engineering', 'ASLI.JK'],
#  ['heavy-constructions-civil-engineering', 'BDKR.JK'],
#  ['banks', 'BNII.JK'],
#  ['banks', 'BBRI.JK'],
#  ['banks', 'PNBN.JK'],
#  ['banks', 'BBCA.JK'],
#  ['banks', 'NISP.JK'],
#  ['banks', 'MEGA.JK'],
#  ['banks', 'AMAR.JK'],
#  ['banks', 'BJBR.JK'],
#  ['banks', 'BBMD.JK'],
#  ['banks', 'BTPS.JK'],
#  ['banks', 'BMRI.JK'],
#  ['banks', 'BBNI.JK'],
#  ['banks', 'BRIS.JK'],
#  ['banks', 'BNLI.JK'],
#  ['banks', 'BNBA.JK'],
#  ['banks', 'BDMN.JK'],
#  ['banks', 'BTPN.JK'],
#  ['banks', 'BBTN.JK'],
#  ['banks', 'BNGA.JK'],
#  ['banks', 'SDRA.JK'],
#  ['banks', 'BMAS.JK'],
#  ['banks', 'BBYB.JK'],
#  ['banks', 'BJTM.JK'],
#  ['banks', 'AGRO.JK'],
#  ['banks', 'ARTO.JK'],
#  ['banks', 'BBHI.JK'],
#  ['banks', 'BGTG.JK'],
#  ['banks', 'BBSI.JK'],
#  ['banks', 'DNAR.JK'],
#  ['banks', 'AGRS.JK'],
#  ['banks', 'BACA.JK'],
#  ['banks', 'BSWD.JK'],
#  ['banks', 'BINA.JK'],
#  ['banks', 'MAYA.JK'],
#  ['banks', 'NOBU.JK'],
#  ['banks', 'PNBS.JK'],
#  ['banks', 'BKSW.JK'],
#  ['banks', 'BABP.JK'],
#  ['banks', 'INPC.JK'],
#  ['banks', 'BEKS.JK'],
#  ['banks', 'BVIC.JK'],
#  ['banks', 'BBKP.JK'],
#  ['banks', 'MASB.JK'],
#  ['banks', 'MCOR.JK'],
#  ['banks', 'BSIM.JK'],
#  ['banks', 'BCIC.JK'],
#  ['banks', 'BANK.JK'],
#  ['holding-investment-companies', 'BPII.JK'],
#  ['holding-investment-companies', 'PEGE.JK'],
#  ['holding-investment-companies', 'SRTG.JK'],
#  ['holding-investment-companies', 'PALM.JK'],
#  ['holding-investment-companies', 'APIC.JK'],
#  ['holding-investment-companies', 'VICO.JK'],
#  ['holding-investment-companies', 'POOL.JK'],
#  ['holding-investment-companies', 'CASA.JK'],
#  ['holding-investment-companies', 'NICK.JK'],
#  ['holding-investment-companies', 'DNET.JK'],
#  ['holding-investment-companies', 'GSMF.JK'],
#  ['holding-investment-companies', 'STAR.JK'],
#  ['holding-investment-companies', 'SMMA.JK'],
#  ['holding-investment-companies', 'SFAN.JK'],
#  ['holding-investment-companies', 'LPPS.JK'],
#  ['holding-investment-companies', 'PLAS.JK'],
#  ['holding-investment-companies', 'MGNA.JK'],
#  ['holding-investment-companies', 'OCAP.JK'],
#  ['holding-investment-companies', 'BCAP.JK'],
#  ['industrial-services', 'ASGR.JK'],
#  ['industrial-services', 'MFMI.JK'],
#  ['industrial-services', 'BLUE.JK'],
#  ['industrial-services', 'PADA.JK'],
#  ['industrial-services', 'LION.JK'],
#  ['industrial-services', 'BINO.JK'],
#  ['industrial-services', 'JTPE.JK'],
#  ['industrial-services', 'VISI.JK'],
#  ['industrial-services', 'SOSS.JK'],
#  ['industrial-services', 'KONI.JK'],
#  ['industrial-services', 'HYGN.JK'],
#  ['industrial-services', 'ICON.JK'],
#  ['industrial-services', 'MHKI.JK'],
#  ['industrial-services', 'CRSN.JK'],
#  ['industrial-services', 'INDX.JK'],
#  ['industrial-services', 'KING.JK'],
#  ['industrial-services', 'MUTU.JK'],
#  ['industrial-services', 'MDRN.JK'],
#  ['industrial-services', 'DYAN.JK'],
#  ['industrial-services', 'TRIL.JK'],
#  ['industrial-services', 'TIRA.JK'],
#  ['consumer-services', 'ENAK.JK'],
#  ['consumer-services', 'LUCY.JK'],
#  ['consumer-services', 'EAST.JK'],
#  ['consumer-services', 'ARTA.JK'],
#  ['consumer-services', 'PZZA.JK'],
#  ['consumer-services', 'PJAA.JK'],
#  ['consumer-services', 'JSPT.JK'],
#  ['consumer-services', 'IDEA.JK'],
#  ['consumer-services', 'BAYU.JK'],
#  ['consumer-services', 'PGLI.JK'],
#  ['consumer-services', 'BOLA.JK'],
#  ['consumer-services', 'CNMA.JK'],
#  ['consumer-services', 'KDTN.JK'],
#  ['consumer-services', 'HRME.JK'],
#  ['consumer-services', 'PANR.JK'],
#  ['consumer-services', 'MINA.JK'],
#  ['consumer-services', 'RAFI.JK'],
#  ['consumer-services', 'PSKT.JK'],
#  ['consumer-services', 'SHID.JK'],
#  ['consumer-services', 'GWSA.JK'],
#  ['consumer-services', 'CLAY.JK'],
#  ['consumer-services', 'GRPH.JK'],
#  ['consumer-services', 'ESTA.JK'],
#  ['consumer-services', 'JIHD.JK'],
#  ['consumer-services', 'BLTZ.JK'],
#  ['consumer-services', 'HOTL.JK'],
#  ['consumer-services', 'BMBL.JK'],
#  ['consumer-services', 'AKKU.JK'],
#  ['consumer-services', 'MABA.JK'],
#  ['consumer-services', 'KOTA.JK'],
#  ['consumer-services', 'CSMI.JK'],
#  ['consumer-services', 'PLAN.JK'],
#  ['consumer-services', 'NATO.JK'],
#  ['consumer-services', 'HOME.JK'],
#  ['consumer-services', 'DFAM.JK'],
#  ['consumer-services', 'BUVA.JK'],
#  ['consumer-services', 'FAST.JK'],
#  ['consumer-services', 'MAMI.JK'],
#  ['consumer-services', 'PDES.JK'],
#  ['consumer-services', 'SNLK.JK'],
#  ['consumer-services', 'PTSP.JK'],
#  ['consumer-services', 'JGLE.JK'],
#  ['consumer-services', 'NUSA.JK'],
#  ['consumer-services', 'GOLF.JK'],
#  ['consumer-services', 'HAJJ.JK'],
#  ['consumer-services', 'BAIK.JK'],
#  ['consumer-services', 'FITT.JK'],
#  ['consumer-services', 'SOTS.JK'],
#  ['consumer-services', 'DUCK.JK'],
#  ['consumer-services', 'PNSE.JK'],
#  ['consumer-services', 'KPIG.JK'],
#  ['consumer-services', 'MAPB.JK'],
#  ['utilities', 'BREN.JK'],
#  ['utilities', 'KEEN.JK'],
#  ['utilities', 'POWR.JK'],
#  ['utilities', 'PGEO.JK'],
#  ['utilities', 'MPOW.JK'],
#  ['utilities', 'TGRA.JK'],
#  ['utilities', 'ARKO.JK'],
#  ['utilities', 'LAPD.JK'],
#  ['utilities', 'HADE.JK'],
#  ['tobacco', 'GGRM.JK'],
#  ['tobacco', 'HMSP.JK'],
#  ['tobacco', 'WIIM.JK'],
#  ['tobacco', 'ITIC.JK'],
#  ['logistics-deliveries', 'SMDR.JK'],
#  ['logistics-deliveries', 'TMAS.JK'],
#  ['logistics-deliveries', 'HATM.JK'],
#  ['logistics-deliveries', 'MPXL.JK'],
#  ['logistics-deliveries', 'PPGL.JK'],
#  ['logistics-deliveries', 'ELPI.JK'],
#  ['logistics-deliveries', 'NELY.JK'],
#  ['logistics-deliveries', 'MITI.JK'],
#  ['logistics-deliveries', 'HAIS.JK'],
#  ['logistics-deliveries', 'LAJU.JK'],
#  ['logistics-deliveries', 'JAYA.JK'],
#  ['logistics-deliveries', 'SAPX.JK'],
#  ['logistics-deliveries', 'MIRA.JK'],
#  ['logistics-deliveries', 'KJEN.JK'],
#  ['logistics-deliveries', 'LOPI.JK'],
#  ['logistics-deliveries', 'PURA.JK'],
#  ['logistics-deliveries', 'KLAS.JK'],
#  ['logistics-deliveries', 'BLTA.JK'],
#  ['logistics-deliveries', 'AKSI.JK'],
#  ['logistics-deliveries', 'SDMU.JK'],
#  ['logistics-deliveries', 'TRUK.JK'],
#  ['logistics-deliveries', 'DEAL.JK'],
#  ['logistics-deliveries', 'GTRA.JK'],
#  ['logistics-deliveries', 'RCCC.JK'],
#  ['logistics-deliveries', 'TNCA.JK'],
#  ['multi-sector-holdings', 'ASII.JK'],
#  ['multi-sector-holdings', 'FOLK.JK'],
#  ['multi-sector-holdings', 'ZBRA.JK'],
#  ['multi-sector-holdings', 'BNBR.JK'],
#  ['multi-sector-holdings', 'BHIT.JK'],
#  ['healthcare-equipment-providers', 'HEAL.JK'],
#  ['healthcare-equipment-providers', 'MIKA.JK'],
#  ['healthcare-equipment-providers', 'OMED.JK'],
#  ['healthcare-equipment-providers', 'DGNS.JK'],
#  ['healthcare-equipment-providers', 'RSGK.JK'],
#  ['healthcare-equipment-providers', 'BMHS.JK'],
#  ['healthcare-equipment-providers', 'IRRA.JK'],
#  ['healthcare-equipment-providers', 'PRDA.JK'],
#  ['healthcare-equipment-providers', 'SILO.JK'],
#  ['healthcare-equipment-providers', 'CARE.JK'],
#  ['healthcare-equipment-providers', 'LABS.JK'],
#  ['healthcare-equipment-providers', 'HALO.JK'],
#  ['healthcare-equipment-providers', 'RSCH.JK'],
#  ['healthcare-equipment-providers', 'MEDS.JK'],
#  ['healthcare-equipment-providers', 'MTMH.JK'],
#  ['healthcare-equipment-providers', 'SAME.JK'],
#  ['healthcare-equipment-providers', 'PRAY.JK'],
#  ['healthcare-equipment-providers', 'MMIX.JK'],
#  ['healthcare-equipment-providers', 'SRAJ.JK'],
#  ['healthcare-equipment-providers', 'SURI.JK'],
#  ['healthcare-equipment-providers', 'PRIM.JK'],
#  ['alternative-energy', 'SEMA.JK'],
#  ['alternative-energy', 'JSKY.JK'],
#  ['automobiles-components', 'SMSM.JK'],
#  ['automobiles-components', 'AUTO.JK'],
#  ['automobiles-components', 'MASA.JK'],
#  ['automobiles-components', 'BRAM.JK'],
#  ['automobiles-components', 'LPIN.JK'],
#  ['automobiles-components', 'INDS.JK'],
#  ['automobiles-components', 'DRMA.JK'],
#  ['automobiles-components', 'GJTL.JK'],
#  ['automobiles-components', 'BOLT.JK'],
#  ['automobiles-components', 'PRAS.JK'],
#  ['automobiles-components', 'AEGS.JK'],
#  ['automobiles-components', 'PART.JK'],
#  ['automobiles-components', 'NIPS.JK'],
#  ['automobiles-components', 'GDYR.JK'],
#  ['automobiles-components', 'ISAP.JK'],
#  ['automobiles-components', 'TYRE.JK'],
#  ['automobiles-components', 'LMAX.JK'],
#  ['automobiles-components', 'VKTR.JK'],
#  ['pharmaceuticals-health-care-research', 'SIDO.JK'],
#  ['pharmaceuticals-health-care-research', 'KAEF.JK'],
#  ['pharmaceuticals-health-care-research', 'MERK.JK'],
#  ['pharmaceuticals-health-care-research', 'SOHO.JK'],
#  ['pharmaceuticals-health-care-research', 'SCPI.JK'],
#  ['pharmaceuticals-health-care-research', 'DVLA.JK'],
#  ['pharmaceuticals-health-care-research', 'TSPC.JK'],
#  ['pharmaceuticals-health-care-research', 'KLBF.JK'],
#  ['pharmaceuticals-health-care-research', 'PEHA.JK'],
#  ['pharmaceuticals-health-care-research', 'INAF.JK'],
#  ['pharmaceuticals-health-care-research', 'PYFA.JK'],
#  ['pharmaceuticals-health-care-research', 'IKPM.JK'],
#  ['pharmaceuticals-health-care-research', 'PEVE.JK'],
#  ['media-entertainment', 'SCMA.JK'],
#  ['media-entertainment', 'MSIN.JK'],
#  ['media-entertainment', 'MNCN.JK'],
#  ['media-entertainment', 'FILM.JK'],
#  ['media-entertainment', 'DOOH.JK'],
#  ['media-entertainment', 'BMTR.JK'],
#  ['media-entertainment', 'MSKY.JK'],
#  ['media-entertainment', 'MARI.JK'],
#  ['media-entertainment', 'MDIA.JK'],
#  ['media-entertainment', 'VIVA.JK'],
#  ['media-entertainment', 'NETV.JK'],
#  ['media-entertainment', 'ABBA.JK'],
#  ['media-entertainment', 'FUTR.JK'],
#  ['media-entertainment', 'DIGI.JK'],
#  ['media-entertainment', 'IPTV.JK'],
#  ['media-entertainment', 'FORU.JK'],
#  ['media-entertainment', 'TMPO.JK'],
#  ['media-entertainment', 'RAAM.JK'],
#  ['basic-materials', 'SAMF.JK'],
#  ['basic-materials', 'AKPI.JK'],
#  ['basic-materials', 'MDKI.JK'],
#  ['basic-materials', 'ALDO.JK'],
#  ['basic-materials', 'SMKL.JK'],
#  ['basic-materials', 'INAI.JK'],
#  ['basic-materials', 'MOLI.JK'],
#  ['basic-materials', 'EKAD.JK'],
#  ['basic-materials', 'PDPP.JK'],
#  ['basic-materials', 'IGAR.JK'],
#  ['basic-materials', 'INCI.JK'],
#  ['basic-materials', 'TINS.JK'],
#  ['basic-materials', 'DPNS.JK'],
#  ['basic-materials', 'UNIC.JK'],
#  ['basic-materials', 'SMGR.JK'],
#  ['basic-materials', 'INKP.JK'],
#  ['basic-materials', 'ISSP.JK'],
#  ['basic-materials', 'TRST.JK'],
#  ['basic-materials', 'FWCT.JK'],
#  ['basic-materials', 'NIKL.JK'],
#  ['basic-materials', 'CITA.JK'],
#  ['basic-materials', 'TPIA.JK'],
#  ['basic-materials', 'SBMA.JK'],
#  ['basic-materials', 'KMTR.JK'],
#  ['basic-materials', 'FASW.JK'],
#  ['basic-materials', 'INCO.JK'],
#  ['basic-materials', 'TBMS.JK'],
#  ['basic-materials', 'WTON.JK'],
#  ['basic-materials', 'SMBR.JK'],
#  ['basic-materials', 'BEBS.JK'],
#  ['basic-materials', 'PBID.JK'],
#  ['basic-materials', 'LTLS.JK'],
#  ['basic-materials', 'BRPT.JK'],
#  ['basic-materials', 'CLPI.JK'],
#  ['basic-materials', 'AGII.JK'],
#  ['basic-materials', 'SMCB.JK'],
#  ['basic-materials', 'TALF.JK'],
#  ['basic-materials', 'INTP.JK'],
#  ['basic-materials', 'WSBP.JK'],
#  ['basic-materials', 'CHEM.JK'],
#  ['basic-materials', 'NCKL.JK'],
#  ['basic-materials', 'GGRP.JK'],
#  ['basic-materials', 'KDSI.JK'],
#  ['basic-materials', 'KKES.JK'],
#  ['basic-materials', 'ANTM.JK'],
#  ['basic-materials', 'IFII.JK'],
#  ['basic-materials', 'ESSA.JK'],
#  ['basic-materials', 'PNGO.JK'],
#  ['basic-materials', 'ESIP.JK'],
#  ['basic-materials', 'TKIM.JK'],
#  ['basic-materials', 'SPMA.JK'],
#  ['basic-materials', 'NICL.JK'],
#  ['basic-materials', 'IFSH.JK'],
#  ['basic-materials', 'AVIA.JK'],
#  ['basic-materials', 'SRSN.JK'],
#  ['basic-materials', 'IPOL.JK'],
#  ['basic-materials', 'BLES.JK'],
#  ['basic-materials', 'SIMA.JK'],
#  ['basic-materials', 'ALMI.JK'],
#  ['basic-materials', 'SOLA.JK'],
#  ['basic-materials', 'APLI.JK'],
#  ['basic-materials', 'INTD.JK'],
#  ['basic-materials', 'KAYU.JK'],
#  ['basic-materials', 'DKFT.JK'],
#  ['basic-materials', 'KBRI.JK'],
#  ['basic-materials', 'BATR.JK'],
#  ['basic-materials', 'KRAS.JK'],
#  ['basic-materials', 'TIRT.JK'],
#  ['basic-materials', 'BAJA.JK'],
#  ['basic-materials', 'NPGF.JK'],
#  ['basic-materials', 'ETWA.JK'],
#  ['basic-materials', 'AYLS.JK'],
#  ['basic-materials', 'EPAC.JK'],
#  ['basic-materials', 'BRNA.JK'],
#  ['basic-materials', 'PPRI.JK'],
#  ['basic-materials', 'SULI.JK'],
#  ['basic-materials', 'SWAT.JK'],
#  ['basic-materials', 'PURE.JK'],
#  ['basic-materials', 'ZINC.JK'],
#  ['basic-materials', 'INCF.JK'],
#  ['basic-materials', 'PICO.JK'],
#  ['basic-materials', 'TDPM.JK'],
#  ['basic-materials', 'LMSH.JK'],
#  ['basic-materials', 'AMMN.JK'],
#  ['basic-materials', 'SQMI.JK'],
#  ['basic-materials', 'BTON.JK'],
#  ['basic-materials', 'OPMS.JK'],
#  ['basic-materials', 'OKAS.JK'],
#  ['basic-materials', 'OBMD.JK'],
#  ['basic-materials', 'BMSR.JK'],
#  ['basic-materials', 'YPAS.JK'],
#  ['basic-materials', 'BRMS.JK'],
#  ['basic-materials', 'FPNI.JK'],
#  ['basic-materials', 'JKSW.JK'],
#  ['basic-materials', 'PACK.JK'],
#  ['basic-materials', 'HKMU.JK'],
#  ['basic-materials', 'CMNT.JK'],
#  ['basic-materials', 'ADMG.JK'],
#  ['basic-materials', 'MBMA.JK'],
#  ['basic-materials', 'PSAB.JK'],
#  ['basic-materials', 'ALKA.JK'],
#  ['basic-materials', 'MDKA.JK'],
#  ['basic-materials', 'NICE.JK'],
#  ['basic-materials', 'INRU.JK'],
#  ['basic-materials', 'ARCI.JK'],
#  ['basic-materials', 'SMGA.JK'],
#  ['basic-materials', 'SMLE.JK'],
#  ['basic-materials', 'GDST.JK'],
#  ['basic-materials', 'CTBN.JK'],
#  ['household-goods', 'GEMA.JK'],
#  ['household-goods', 'MICE.JK'],
#  ['household-goods', 'CINT.JK'],
#  ['household-goods', 'WOOD.JK'],
#  ['household-goods', 'SCNP.JK'],
#  ['household-goods', 'OLIV.JK'],
#  ['household-goods', 'CBMF.JK'],
#  ['household-goods', 'KICI.JK'],
#  ['household-goods', 'LIVE.JK'],
#  ['household-goods', 'MGLV.JK'],
#  ['household-goods', 'LFLO.JK'],
#  ['household-goods', 'MEJA.JK'],
#  ['household-goods', 'SOFA.JK'],
#  ['household-goods', 'LMPI.JK'],
#  ['technology-hardware-equipment', 'LUCK.JK'],
#  ['technology-hardware-equipment', 'ZYRX.JK'],
#  ['technology-hardware-equipment', 'PTSN.JK'],
#  ['technology-hardware-equipment', 'MTDL.JK'],
#  ['technology-hardware-equipment', 'AXIO.JK'],
#  ['technology-hardware-equipment', 'GLVA.JK'],
#  ['technology-hardware-equipment', 'CHIP.JK'],
#  ['technology-hardware-equipment', 'MENN.JK'],
#  ['technology-hardware-equipment', 'MSTI.JK'],
#  ['technology-hardware-equipment', 'NINE.JK'],
#  ['technology-hardware-equipment', 'IOTF.JK'],
#  ['properties-real-estate', 'KBAG.JK'],
#  ['properties-real-estate', 'ADCP.JK'],
#  ['properties-real-estate', 'PLIN.JK'],
#  ['properties-real-estate', 'LPCK.JK'],
#  ['properties-real-estate', 'RELF.JK'],
#  ['properties-real-estate', 'ATAP.JK'],
#  ['properties-real-estate', 'CTRA.JK'],
#  ['properties-real-estate', 'PUDP.JK'],
#  ['properties-real-estate', 'DMAS.JK'],
#  ['properties-real-estate', 'NZIA.JK'],
#  ['properties-real-estate', 'INPP.JK'],
#  ['properties-real-estate', 'GMTD.JK'],
#  ['properties-real-estate', 'PWON.JK'],
#  ['properties-real-estate', 'JRPT.JK'],
#  ['properties-real-estate', 'PPRO.JK'],
#  ['properties-real-estate', 'MTLA.JK'],
#  ['properties-real-estate', 'SMRA.JK'],
#  ['properties-real-estate', 'CBPE.JK'],
#  ['properties-real-estate', 'PURI.JK'],
#  ['properties-real-estate', 'RDTX.JK'],
#  ['properties-real-estate', 'MKPI.JK'],
#  ['properties-real-estate', 'BSBK.JK'],
#  ['properties-real-estate', 'DUTI.JK'],
#  ['properties-real-estate', 'GPRA.JK'],
#  ['properties-real-estate', 'SWID.JK'],
#  ['properties-real-estate', 'AMAN.JK'],
#  ['properties-real-estate', 'KOCI.JK'],
#  ['properties-real-estate', 'NIRO.JK'],
#  ['properties-real-estate', 'FORZ.JK'],
#  ['properties-real-estate', 'CITY.JK'],
#  ['properties-real-estate', 'DADA.JK'],
#  ['properties-real-estate', 'MSIE.JK'],
#  ['properties-real-estate', 'GRIA.JK'],
#  ['properties-real-estate', 'REAL.JK'],
#  ['properties-real-estate', 'MPRO.JK'],
#  ['properties-real-estate', 'HBAT.JK'],
#  ['properties-real-estate', 'DILD.JK'],
#  ['properties-real-estate', 'HOMI.JK'],
#  ['properties-real-estate', 'BSDE.JK'],
#  ['properties-real-estate', 'ELTY.JK'],
#  ['properties-real-estate', 'CPRI.JK'],
#  ['properties-real-estate', 'BAPI.JK'],
#  ['properties-real-estate', 'POLI.JK'],
#  ['properties-real-estate', 'BBSS.JK'],
#  ['properties-real-estate', 'RODA.JK'],
#  ['properties-real-estate', 'ASRI.JK'],
#  ['properties-real-estate', 'APLN.JK'],
#  ['properties-real-estate', 'WINR.JK'],
#  ['properties-real-estate', 'LAND.JK'],
#  ['properties-real-estate', 'CSIS.JK'],
#  ['properties-real-estate', 'FMII.JK'],
#  ['properties-real-estate', 'LPKR.JK'],
#  ['properties-real-estate', 'NASA.JK'],
#  ['properties-real-estate', 'IPAC.JK'],
#  ['properties-real-estate', 'ASPI.JK'],
#  ['properties-real-estate', 'INDO.JK'],
#  ['properties-real-estate', 'BKDP.JK'],
#  ['properties-real-estate', 'KIJA.JK'],
#  ['properties-real-estate', 'MDLN.JK'],
#  ['properties-real-estate', 'SAGE.JK'],
#  ['properties-real-estate', 'BAPA.JK'],
#  ['properties-real-estate', 'LPLI.JK'],
#  ['properties-real-estate', 'LCGP.JK'],
#  ['properties-real-estate', 'SMDM.JK'],
#  ['properties-real-estate', 'MMLP.JK'],
#  ['properties-real-estate', 'URBN.JK'],
#  ['properties-real-estate', 'COWL.JK'],
#  ['properties-real-estate', 'BKSL.JK'],
#  ['properties-real-estate', 'EMDE.JK'],
#  ['properties-real-estate', 'ROCK.JK'],
#  ['properties-real-estate', 'GAMA.JK'],
#  ['properties-real-estate', 'BIKA.JK'],
#  ['properties-real-estate', 'TRUE.JK'],
#  ['properties-real-estate', 'POLL.JK'],
#  ['properties-real-estate', 'ARMY.JK'],
#  ['properties-real-estate', 'OMRE.JK'],
#  ['properties-real-estate', 'MTSM.JK'],
#  ['properties-real-estate', 'UANG.JK'],
#  ['properties-real-estate', 'TARA.JK'],
#  ['properties-real-estate', 'RISE.JK'],
#  ['properties-real-estate', 'MYRX.JK'],
#  ['properties-real-estate', 'DART.JK'],
#  ['properties-real-estate', 'VAST.JK'],
#  ['properties-real-estate', 'BEST.JK'],
#  ['properties-real-estate', 'BCIP.JK'],
#  ['properties-real-estate', 'PAMG.JK'],
#  ['properties-real-estate', 'TRIN.JK'],
#  ['properties-real-estate', 'RIMO.JK'],
#  ['properties-real-estate', 'SATU.JK'],
#  ['properties-real-estate', 'RBMS.JK'],
#  ['properties-real-estate', 'POSA.JK'],
#  ['properties-real-estate', 'BIPP.JK'],
#  ['industrial-goods', 'KBLI.JK'],
#  ['industrial-goods', 'TOTO.JK'],
#  ['industrial-goods', 'MARK.JK'],
#  ['industrial-goods', 'KBLM.JK'],
#  ['industrial-goods', 'JECC.JK'],
#  ['industrial-goods', 'ARNA.JK'],
#  ['industrial-goods', 'MLIA.JK'],
#  ['industrial-goods', 'SPTO.JK'],
#  ['industrial-goods', 'IKBI.JK'],
#  ['industrial-goods', 'UNTR.JK'],
#  ['industrial-goods', 'KUAS.JK'],
#  ['industrial-goods', 'NTBK.JK'],
#  ['industrial-goods', 'AMFG.JK'],
#  ['industrial-goods', 'HEXA.JK'],
#  ['industrial-goods', 'IMPC.JK'],
#  ['industrial-goods', 'SCCO.JK'],
#  ['industrial-goods', 'AMIN.JK'],
#  ['industrial-goods', 'CCSI.JK'],
#  ['industrial-goods', 'KOBX.JK'],
#  ['industrial-goods', 'SKRN.JK'],
#  ['industrial-goods', 'KIAS.JK'],
#  ['industrial-goods', 'PIPA.JK'],
#  ['industrial-goods', 'KPAL.JK'],
#  ['industrial-goods', 'SINI.JK'],
#  ['industrial-goods', 'INTA.JK'],
#  ['industrial-goods', 'GPSO.JK'],
#  ['industrial-goods', 'IKAI.JK'],
#  ['industrial-goods', 'HOPE.JK'],
#  ['industrial-goods', 'KRAH.JK'],
#  ['industrial-goods', 'CAKK.JK'],
#  ['industrial-goods', 'IBFN.JK'],
#  ['industrial-goods', 'WIDI.JK'],
#  ['industrial-goods', 'KOIN.JK'],
#  ['industrial-goods', 'APII.JK'],
#  ['industrial-goods', 'LABA.JK'],
#  ['industrial-goods', 'SMIL.JK'],
#  ['industrial-goods', 'CTTH.JK'],
#  ['industrial-goods', 'PTMP.JK'],
#  ['industrial-goods', 'ARKA.JK'],
#  ['industrial-goods', 'VOKS.JK'],
#  ['transportation', 'JSMR.JK'],
#  ['transportation', 'META.JK'],
#  ['transportation', 'IPCM.JK'],
#  ['transportation', 'BIRD.JK'],
#  ['transportation', 'IMJS.JK'],
#  ['transportation', 'TRJA.JK'],
#  ['transportation', 'IPCC.JK'],
#  ['transportation', 'ASSA.JK'],
#  ['transportation', 'CMPP.JK'],
#  ['transportation', 'GIAA.JK'],
#  ['transportation', 'WEHA.JK'],
#  ['transportation', 'HELI.JK'],
#  ['transportation', 'GMFI.JK'],
#  ['transportation', 'KARW.JK'],
#  ['transportation', 'CASS.JK'],
#  ['transportation', 'BPTR.JK'],
#  ['transportation', 'TAXI.JK'],
#  ['transportation', 'CMNP.JK'],
#  ['transportation', 'SAFE.JK'],
#  ['transportation', 'LRNA.JK'],
#  ['transportation', 'PORT.JK'],
#  ['nondurable-household-products', 'KINO.JK'],
#  ['nondurable-household-products', 'VICI.JK'],
#  ['nondurable-household-products', 'UNVR.JK'],
#  ['nondurable-household-products', 'TCID.JK'],
#  ['nondurable-household-products', 'UCID.JK'],
#  ['nondurable-household-products', 'MBTO.JK'],
#  ['nondurable-household-products', 'NANO.JK'],
#  ['nondurable-household-products', 'EURO.JK'],
#  ['nondurable-household-products', 'KPAS.JK'],
#  ['nondurable-household-products', 'MSJA.JK'],
#  ['nondurable-household-products', 'FLMC.JK'],
#  ['nondurable-household-products', 'MRAT.JK'],
#  ['transportation-infrastructure', 'JSMR.JK'],
#  ['transportation-infrastructure', 'META.JK'],
#  ['transportation-infrastructure', 'IPCM.JK'],
#  ['transportation-infrastructure', 'IPCC.JK'],
#  ['transportation-infrastructure', 'GMFI.JK'],
#  ['transportation-infrastructure', 'KARW.JK'],
#  ['transportation-infrastructure', 'CASS.JK'],
#  ['transportation-infrastructure', 'CMNP.JK'],
#  ['transportation-infrastructure', 'PORT.JK'],
#  ['food-staples-retailing', 'EPMT.JK'],
#  ['food-staples-retailing', 'BUAH.JK'],
#  ['food-staples-retailing', 'AMRT.JK'],
#  ['food-staples-retailing', 'SDPC.JK'],
#  ['food-staples-retailing', 'KMDS.JK'],
#  ['food-staples-retailing', 'MIDI.JK'],
#  ['food-staples-retailing', 'RANC.JK'],
#  ['food-staples-retailing', 'DAYA.JK'],
#  ['food-staples-retailing', 'WICO.JK'],
#  ['food-staples-retailing', 'PCAR.JK'],
#  ['food-staples-retailing', 'MLPL.JK'],
#  ['food-staples-retailing', 'DMND.JK'],
#  ['food-staples-retailing', 'MPPA.JK'],
#  ['food-staples-retailing', 'HERO.JK'],
#  ['food-beverage', 'WMUU.JK'],
#  ['food-beverage', 'MYOR.JK'],
#  ['food-beverage', 'BOBA.JK'],
#  ['food-beverage', 'TGKA.JK'],
#  ['food-beverage', 'SGRO.JK'],
#  ['food-beverage', 'CLEO.JK'],
#  ['food-beverage', 'FISH.JK'],
#  ['food-beverage', 'MLBI.JK'],
#  ['food-beverage', 'ICBP.JK'],
#  ['food-beverage', 'SMAR.JK'],
#  ['food-beverage', 'NAYZ.JK'],
#  ['food-beverage', 'INDF.JK'],
#  ['food-beverage', 'CBUT.JK'],
#  ['food-beverage', 'CMRY.JK'],
#  ['food-beverage', 'CEKA.JK'],
#  ['food-beverage', 'BISI.JK'],
#  ['food-beverage', 'TBLA.JK'],
#  ['food-beverage', 'AALI.JK'],
#  ['food-beverage', 'PMMP.JK'],
#  ['food-beverage', 'CAMP.JK'],
#  ['food-beverage', 'PTPS.JK'],
#  ['food-beverage', 'SKLT.JK'],
#  ['food-beverage', 'KEJU.JK'],
#  ['food-beverage', 'DSNG.JK'],
#  ['food-beverage', 'DLTA.JK'],
#  ['food-beverage', 'WINE.JK'],
#  ['food-beverage', 'JPFA.JK'],
#  ['food-beverage', 'OILS.JK'],
#  ['food-beverage', 'LSIP.JK'],
#  ['food-beverage', 'SSMS.JK'],
#  ['food-beverage', 'MKTR.JK'],
#  ['food-beverage', 'SKBM.JK'],
#  ['food-beverage', 'SIMP.JK'],
#  ['food-beverage', 'SOUL.JK'],
#  ['food-beverage', 'STTP.JK'],
#  ['food-beverage', 'TRGU.JK'],
#  ['food-beverage', 'GOOD.JK'],
#  ['food-beverage', 'HOKI.JK'],
#  ['food-beverage', 'TLDN.JK'],
#  ['food-beverage', 'ANJT.JK'],
#  ['food-beverage', 'ULTJ.JK'],
#  ['food-beverage', 'MGRO.JK'],
#  ['food-beverage', 'TAPG.JK'],
#  ['food-beverage', 'STAA.JK'],
#  ['food-beverage', 'CSRA.JK'],
#  ['food-beverage', 'CPIN.JK'],
#  ['food-beverage', 'ROTI.JK'],
#  ['food-beverage', 'BEER.JK'],
#  ['food-beverage', 'BUDI.JK'],
#  ['food-beverage', 'CRAB.JK'],
#  ['food-beverage', 'ENZO.JK'],
#  ['food-beverage', 'PGUN.JK'],
#  ['food-beverage', 'DEWI.JK'],
#  ['food-beverage', 'AYAM.JK'],
#  ['food-beverage', 'COCO.JK'],
#  ['food-beverage', 'TGUK.JK'],
#  ['food-beverage', 'SIPD.JK'],
#  ['food-beverage', 'JAWA.JK'],
#  ['food-beverage', 'AMMS.JK'],
#  ['food-beverage', 'NASI.JK'],
#  ['food-beverage', 'MAIN.JK'],
#  ['food-beverage', 'ANDI.JK'],
#  ['food-beverage', 'ALTO.JK'],
#  ['food-beverage', 'BWPT.JK'],
#  ['food-beverage', 'WAPO.JK'],
#  ['food-beverage', 'FOOD.JK'],
#  ['food-beverage', 'BTEK.JK'],
#  ['food-beverage', 'TAYS.JK'],
#  ['food-beverage', 'PSGO.JK'],
#  ['food-beverage', 'WMPP.JK'],
#  ['food-beverage', 'CPRO.JK'],
#  ['food-beverage', 'ASHA.JK'],
#  ['food-beverage', 'GRPM.JK'],
#  ['food-beverage', 'MAXI.JK'],
#  ['food-beverage', 'UDNG.JK'],
#  ['food-beverage', 'GOLL.JK'],
#  ['food-beverage', 'GULA.JK'],
#  ['food-beverage', 'GZCO.JK'],
#  ['food-beverage', 'ADES.JK'],
#  ['food-beverage', 'AISA.JK'],
#  ['food-beverage', 'DPUM.JK'],
#  ['food-beverage', 'UNSP.JK'],
#  ['food-beverage', 'PANI.JK'],
#  ['food-beverage', 'ISEA.JK'],
#  ['food-beverage', 'FAPA.JK'],
#  ['food-beverage', 'DSFI.JK'],
#  ['food-beverage', 'BEEF.JK'],
#  ['food-beverage', 'JARR.JK'],
#  ['food-beverage', 'AGAR.JK'],
#  ['food-beverage', 'GUNA.JK'],
#  ['food-beverage', 'STRK.JK'],
#  ['food-beverage', 'IKAN.JK'],
#  ['food-beverage', 'NSSS.JK'],
#  ['food-beverage', 'MAGP.JK'],
#  ['food-beverage', 'IBOS.JK'],
#  ['food-beverage', 'PSDN.JK'],
#  ['food-beverage', 'NEST.JK'],
#  ['food-beverage', 'IPPE.JK'],
#  ['leisure-goods', 'BIKE.JK'],
#  ['leisure-goods', 'UNTD.JK'],
#  ['leisure-goods', 'TOYS.JK'],
#  ['leisure-goods', 'IIKP.JK'],
#  ['leisure-goods', 'DOSS.JK'],
#  ['retailing', 'EPMT.JK'],
#  ['retailing', 'ACES.JK'],
#  ['retailing', 'MAPI.JK'],
#  ['retailing', 'ERAA.JK'],
#  ['retailing', 'PMJS.JK'],
#  ['retailing', 'MAPA.JK'],
#  ['retailing', 'ECII.JK'],
#  ['retailing', 'BAUT.JK'],
#  ['retailing', 'LPPF.JK'],
#  ['retailing', 'MPMX.JK'],
#  ['retailing', 'BUAH.JK'],
#  ['retailing', 'ZONE.JK'],
#  ['retailing', 'SLIS.JK'],
#  ['retailing', 'AMRT.JK'],
#  ['retailing', 'CSAP.JK'],
#  ['retailing', 'UFOE.JK'],
#  ['retailing', 'SDPC.JK'],
#  ['retailing', 'KMDS.JK'],
#  ['retailing', 'MIDI.JK'],
#  ['retailing', 'RALS.JK'],
#  ['retailing', 'RANC.JK'],
#  ['retailing', 'DEPO.JK'],
#  ['retailing', 'IMAS.JK'],
#  ['retailing', 'DAYA.JK'],
#  ['retailing', 'ASLC.JK'],
#  ['retailing', 'BABY.JK'],
#  ['retailing', 'MKNT.JK'],
#  ['retailing', 'WICO.JK'],
#  ['retailing', 'TOOL.JK'],
#  ['retailing', 'CARS.JK'],
#  ['retailing', 'PCAR.JK'],
#  ['retailing', 'ZATA.JK'],
#  ['retailing', 'MLPL.JK'],
#  ['retailing', 'TELE.JK'],
#  ['retailing', 'DMND.JK'],
#  ['retailing', 'MPPA.JK'],
#  ['retailing', 'HERO.JK'],
#  ['retailing', 'ERAL.JK'],
#  ['retailing', 'KLIN.JK'],
#  ['retailing', 'BOGA.JK'],
#  ['retailing', 'GLOB.JK'],
#  ['retailing', 'TRIO.JK'],
#  ['retailing', 'YELO.JK'],
#  ['retailing', 'SONA.JK']]

# %%
df = pd.DataFrame(result_data, columns=["subsectors", "company"])
df["subsectors"] = df["subsectors"].str.replace("-"," ")
df["subsectors"] = df["subsectors"].str.title()
df_grouped = df.groupby('subsectors').size().reset_index(name="total_companies")

# %%
df_grouped.head()
# Out:
#                subsectors  total_companies
# 0      Alternative Energy                2
# 1    Apparel Luxury Goods               24
# 2  Automobiles Components               18
# 3                   Banks               47
# 4         Basic Materials              109

# %%
df_grouped.shape
# Out:
# (33, 2)

# %%
df_grouped.to_csv('df_grouped.csv')

# %%
alt.Chart(df_grouped).mark_bar().encode(x='subsectors', y='total_companies')
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_grouped).mark_bar().encode(x='total_companies', y=alt.X('subsectors:O', sort='-y'), tooltip=['subsectors', 'total_companies'])
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_grouped).mark_line(interpolate='natural').encode(x=alt.X('total_companies'), y=alt.X('subsectors', sort='-y'))
